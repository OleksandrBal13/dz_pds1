# %% [markdown]
# #### Завдання 2
# При вивченні випадкової величини $Х$ у результаті 40 незалежних спостережень дістали вибірку: 10, 13, 10, 9, 9, 12, 12, 6, 7, 9, 8, 9, 11, 9, 14, 13, 9, 8, 8, 7, 10, 10, 11, 11, 11, 12, 8, 7,9, 10, 14, 13, 8, 8, 9, 10, 11, 11, 12, 12. Побудувати дискретний статистичний розподіл для цієї вибірки, а також полігон частот і $F(x)$. Знайти моду та медіану.

# %%
import matplotlib.pyplot as plt

x = [10, 13, 10, 9, 9, 12, 12, 6, 7, 9, 8, 9, 11, 9, 14, 13, 9, 8, 8, 7,
     10, 10, 11, 11, 11, 12, 8, 7, 9, 10, 14, 13, 8, 8, 9, 10, 11, 11, 12, 12]
y = [6, 7, 8, 9, 10, 11, 12, 13, 14]

q = len(x)
print(q)
# Out:
# 40

# %%
a = []
for p in y:
    z = 0
    for i in x:
        if i == p:
            z += 1
    a.append(z)
b = {}
for i in range(len(y)):
    b[y[i]] = a[i]

plt.title("Статистичний розподіл частот")
plt.plot(y,a)
plt.show()

# %%
a = []
for p in y:
    z = 0
    for i in x:
        if i == p:
            z += 1
    a.append(z/q)
b = {}
for i in range(len(y)):
    b[y[i]] = a[i]

plt.title("Статистичний розподіл відносних частот:")
plt.plot(y,a)
plt.show()

# %%
a = []
for p in y:
    z = 0
    for i in x:
        if i == p:
            z += 1
    a.append(z/q)
d = []
e = 0
for i in a:
    e += i
    d.append(e)
b = {}
for i in range(len(y)):
    b[y[i]] = d[i]
print(b)
plt.title("Функція розподілу:")
plt.plot(y,d)
plt.show()
# Out:
# {6: 0.025, 7: 0.1, 8: 0.25, 9: 0.45, 10: 0.6, 11: 0.75, 12: 0.875, 13: 0.95, 14: 1.0}

# %%
a = []
for p in y:
    z = 0
    for i in x:
        if i == p:
            z += 1
    a.append(z)
b = {}
for i in range(len(y)):
    b[y[i]] = a[i]
if __name__ == '__main__':
    x = max(b, key=b.get)
    print(f"Мода = {x} і повторюється {max(a)} разів")
# Out:
# Мода = 9 і повторюється 8 разів

# %%
x = [10, 13, 10, 9, 9, 12, 12, 6, 7, 9, 8, 9, 11, 9, 14, 13, 9, 8, 8, 7,
     10, 10, 11, 11, 11, 12, 8, 7, 9, 10, 14, 13, 8, 8, 9, 10, 11, 11, 12, 12]
x = sorted(x)
med = 0
if q % 2 == 0:
    med = (x[q//2]+x[q//2+1])/2
else:
    med = x[q // 2]

print(f"Медіана = {med}")
# Out:
# Медіана = 10.0
